# %% [markdown]
# # Project Readiness Review
#
# This notebook is the starting point for the v0.4.0 Notebook and Data Exploration Foundation milestone.
#
# It reviews the current state before deeper exploratory data analysis and before real AI/ML training.

# %% [markdown]
# ## Current Project State
#
# - v0.1.0 introduced the transparent MVP risk engine.
# - v0.2.0 introduced the weather sample pipeline.
# - v0.2.1 fixed no-risk weather signal classification.
# - v0.3.0 introduced the geospatial foundation layer.
#
# The project is not yet training a real ML model because verified training labels and a model-ready feature table are still needed.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
PROJECT_ROOT

# %%
from floodrisk.version import __version__

__version__

# %%
from floodrisk.geospatial.summary import load_geospatial_summary

geospatial_summary = load_geospatial_summary(PROJECT_ROOT)
geospatial_summary

# %% [markdown]
# ## Readiness Questions
#
# Before real ML training starts, answer these questions:
#
# 1. What will be the target label?
# 2. Which dataset provides historical flood labels?
# 3. Which features are stable and reproducible?
# 4. Which geospatial boundary files are verified and valid?
# 5. What baseline model is appropriate for the first experiment?
